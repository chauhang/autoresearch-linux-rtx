# %% [markdown]
# # Autoresearch Experiment Analysis
#
# Analysis of autonomous hyperparameter tuning results from `results.tsv`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the TSV (tab-separated, 5 columns: commit, val_bpb, memory_gb, status, description)
df = pd.read_csv("results.tsv", sep="\t")
df["val_bpb"] = pd.to_numeric(df["val_bpb"], errors="coerce")
df["memory_gb"] = pd.to_numeric(df["memory_gb"], errors="coerce")
df["status"] = df["status"].str.strip().str.upper()

print(f"Total experiments: {len(df)}")
print(f"Columns: {list(df.columns)}")
df.head(10)
# Out:
# Total experiments: 84
# Columns: ['commit', 'val_bpb', 'memory_gb', 'status', 'description']
#     commit   val_bpb  memory_gb   status  \
# 0  46294df  1.228006        1.7     KEEP
# 1  70a4278  1.227179        1.7  DISCARD
# 2  0bb1b3c  1.028962        1.4     KEEP
# 3  0bb1b3c  0.794208        2.3     KEEP
# 4  3bb451d  0.777060        2.3     KEEP
# 5  3bb451d  0.775165        2.3     KEEP
# 6  cb6bd98  0.769305        2.3     KEEP
# 7  cb6bd98  0.757124        2.2     KEEP
# 8  c4f7175  0.751611        2.2     KEEP
# 9  c4f7175  0.707381        2.1     KEEP
#
#                                          description
# 0                                           baseline
# 1  torch.compile on Linux: no throughput gain (sa...
# 2         DEPTH=6: 36 steps 18.9M tokens 42K tok/sec
# 3  DEPTH=4 (--depth 4): 62 steps 32.5M tokens 89K...
# 4               WARMDOWN_RATIO 0.5->0.3: GPU0 result
# 5        WARMDOWN_RATIO 0.5->0.3: GPU1 result (best)
# 6                          WARMDOWN=0.2 DEPTH=4 GPU0
# 7               WARMDOWN=0.2 DEPTH=3 GPU1 (new best)
# 8                          WARMDOWN=0.1 DEPTH=3 GPU0
# 9        WARMDOWN=0.1 DEPTH=2 GPU1 (best: 137 steps)

# %%
counts = df["status"].value_counts()
print("Experiment outcomes:")
print(counts.to_string())

n_keep = counts.get("KEEP", 0)
n_discard = counts.get("DISCARD", 0)
n_crash = counts.get("CRASH", 0)
n_decided = n_keep + n_discard
if n_decided > 0:
    print(f"\nKeep rate: {n_keep}/{n_decided} = {n_keep / n_decided:.1%}")
# Out:
# Experiment outcomes:
# status
# DISCARD    47
# KEEP       37
#
# Keep rate: 37/84 = 44.0%

# %%
# Show all KEPT experiments (the improvements that stuck)
kept = df[df["status"] == "KEEP"].copy()
print(f"KEPT experiments ({len(kept)} total):\n")
for i, row in kept.iterrows():
    bpb = row["val_bpb"]
    desc = row["description"]
    print(f"  #{i:3d}  bpb={bpb:.6f}  mem={row['memory_gb']:.1f}GB  {desc}")
# Out:
# KEPT experiments (37 total):
#
#   #  0  bpb=1.228006  mem=1.7GB  baseline
#   #  2  bpb=1.028962  mem=1.4GB  DEPTH=6: 36 steps 18.9M tokens 42K tok/sec
#   #  3  bpb=0.794208  mem=2.3GB  DEPTH=4 (--depth 4): 62 steps 32.5M tokens 89K tok/sec
#   #  4  bpb=0.777060  mem=2.3GB  WARMDOWN_RATIO 0.5->0.3: GPU0 result
#   #  5  bpb=0.775165  mem=2.3GB  WARMDOWN_RATIO 0.5->0.3: GPU1 result (best)
#   #  6  bpb=0.769305  mem=2.3GB  WARMDOWN=0.2 DEPTH=4 GPU0
#   #  7  bpb=0.757124  mem=2.2GB  WARMDOWN=0.2 DEPTH=3 GPU1 (new best)
#   #  8  bpb=0.751611  mem=2.2GB  WARMDOWN=0.1 DEPTH=3 GPU0
#   #  9  bpb=0.707381  mem=2.1GB  WARMDOWN=0.1 DEPTH=2 GPU1 (best: 137 steps)
#   # 10  bpb=0.704718  mem=8.2GB  DEPTH=2 WARMDOWN=0.1 batch=32 GPU0 (after ollama stop)
#   # 11  bpb=0.701946  mem=8.2GB  DEPTH=2 WARMDOWN=0.1 batch=32 GPU1 (new best: 141 steps 227K t/s)
#   # 17  bpb=0.697069  mem=8.2GB  MATRIX_LR=0.06 GPU1 (141 steps, new best)
#   # 19  bpb=0.677509  mem=8.4GB  ASPECT_RATIO=128 n_embd=256 LR=0.06 GPU1 (96 steps 50M tok NEW BEST)
#   # 20  bpb=0.676671  mem=8.4GB  MATRIX_LR=0.08 n_embd=256 GPU0 (95 steps new best)
#   # 26  bpb=0.672712  mem=8.4GB  WARMDOWN=0.15 GPU0 (new best)
#   # 35  bpb=0.650603  mem=8.3GB  HEAD_DIM=64 ASPECT_RATIO=96 n_embd=192 GPU1 (129 steps NEW BEST)
#   # 42  bpb=0.606253  mem=8.3GB  TOTAL_BATCH=2^18 GPU0 (246 steps 62M tok NEW BEST)
#   # 43  bpb=0.601585  mem=8.3GB  TOTAL_BATCH=2^17 GPU1 (482 steps 63M tok BEST; smaller batch=more steps)
#   # 44  bpb=0.563299  mem=8.3GB  TOTAL_BATCH=2^16 GPU0 (939 steps 61M tok NEW BEST)
#   # 46  bpb=0.563205  mem=4.2GB  TOTAL_BATCH=2^15 GPU0 (1832 steps 60M tok; same as 2^16 but half VRAM)
#   # 48  bpb=0.550721  mem=4.3GB  n_embd=256 AR=128 2^15 GPU0 (1549 steps 50M tok NEW BEST)
#   # 49  bpb=0.559632  mem=8.3GB  WARMDOWN=0.25 2^16 GPU1 (better than 0.15 at 939 steps)
#   # 50  bpb=0.545657  mem=4.3GB  n_embd=256 WARMDOWN=0.25 GPU0 (1529 steps new best)
#   # 51  bpb=0.537454  mem=4.3GB  n_embd=320 AR=160 WARMDOWN=0.25 GPU1 (1293 steps 42M tok BEST)
#   # 52  bpb=0.534312  mem=4.3GB  n_embd=384 AR=192 GPU0 (1136 steps 37M tok NEW BEST)
#   # 55  bpb=0.531618  mem=4.3GB  MATRIX_LR=0.06 GPU1 (better than 0.08; NEW BEST)
#   # 57  bpb=0.531004  mem=4.3GB  MATRIX_LR=0.05 GPU1 (marginal new best)
#   # 59  bpb=0.529474  mem=4.3GB  WARMDOWN=0.30 GPU1 (new best! more cooldown helps)
#   # 60  bpb=0.527978  mem=4.3GB  WARMDOWN=0.35 GPU0 (better; more cooldown keeps winning)
#   # 61  bpb=0.526829  mem=4.3GB  WARMDOWN=0.40 GPU1 (new best; long cooldown=better)
#   # 62  bpb=0.526012  mem=4.3GB  WARMDOWN=0.50 GPU0 (still improving)
#   # 63  bpb=0.525183  mem=4.3GB  WARMDOWN=0.60 GPU1 (new best; 60% cooldown works!)
#   # 65  bpb=0.525120  mem=4.3GB  WARMDOWN=0.80 GPU1 (tied with 0.60; plateau reached)
#   # 66  bpb=0.524714  mem=4.3GB  WEIGHT_DECAY=0.1 GPU0 (marginal best; lower WD better for 384)
#   # 69  bpb=0.523885  mem=4.3GB  EMBEDDING_LR=0.8 GPU1 (new best)
#   # 73  bpb=0.522506  mem=4.3GB  ADAM beta2=0.99 GPU1 (new best; more stable second moment)
#   # 77  bpb=0.517530  mem=4.4GB  DEPTH=3 n_embd=320 AR=96 GPU1 (997 steps NEW BEST)

# %% [markdown]
# ## Val BPB Over Time
#
# Track how the best (kept) val_bpb evolves as experiments progress. The running minimum shows the "frontier" -- the best result achieved so far.

# %%
fig, ax = plt.subplots(figsize=(16, 8))

# Filter out crashes for plotting
valid = df[df["status"] != "CRASH"].copy()
valid = valid.reset_index(drop=True)

baseline_bpb = valid.loc[0, "val_bpb"]

# Only plot points at or below baseline (the interesting region)
below = valid[valid["val_bpb"] <= baseline_bpb + 0.0005]

# Plot discarded as faint background dots
disc = below[below["status"] == "DISCARD"]
ax.scatter(disc.index, disc["val_bpb"],
           c="#cccccc", s=12, alpha=0.5, zorder=2, label="Discarded")

# Plot kept experiments as prominent green dots
kept_v = below[below["status"] == "KEEP"]
ax.scatter(kept_v.index, kept_v["val_bpb"],
           c="#2ecc71", s=50, zorder=4, label="Kept", edgecolors="black", linewidths=0.5)

# Running minimum step line
kept_mask = valid["status"] == "KEEP"
kept_idx = valid.index[kept_mask]
kept_bpb = valid.loc[kept_mask, "val_bpb"]
running_min = kept_bpb.cummin()
ax.step(kept_idx, running_min, where="post", color="#27ae60",
        linewidth=2, alpha=0.7, zorder=3, label="Running best")

# Label each kept experiment with its description
for idx, bpb in zip(kept_idx, kept_bpb):
    desc = str(valid.loc[idx, "description"]).strip()
    if len(desc) > 45:
        desc = desc[:42] + "..."

    ax.annotate(desc, (idx, bpb),
                textcoords="offset points",
                xytext=(6, 6), fontsize=8.0,
                color="#1a7a3a", alpha=0.9,
                rotation=30, ha="left", va="bottom")

n_total = len(df)
n_kept = len(df[df["status"] == "KEEP"])
ax.set_xlabel("Experiment #", fontsize=12)
ax.set_ylabel("Validation BPB (lower is better)", fontsize=12)
ax.set_title(f"Autoresearch Progress (RTX 3060 Ubuntu): {n_total} Experiments, {n_kept} Kept Improvements", fontsize=14)
ax.legend(loc="upper right", fontsize=9)
ax.grid(True, alpha=0.2)

# Y-axis: from just below best to just above baseline
best_bpb = kept_bpb.min()
margin = (baseline_bpb - best_bpb) * 0.15
ax.set_ylim(best_bpb - margin, baseline_bpb + margin)

plt.tight_layout()
plt.savefig("progress.png", dpi=150, bbox_inches="tight")
plt.show()
print("Saved to progress.png")
# Out:
# Saved to progress.png

# %% [markdown]
# ## Summary Statistics

# %%
# Summary stats
kept = df[df["status"] == "KEEP"].copy()
baseline_bpb = df.iloc[0]["val_bpb"]
best_bpb = kept["val_bpb"].min()
best_row = kept.loc[kept["val_bpb"].idxmin()]

print(f"Baseline val_bpb:  {baseline_bpb:.6f}")
print(f"Best val_bpb:      {best_bpb:.6f}")
print(f"Total improvement: {baseline_bpb - best_bpb:.6f} ({(baseline_bpb - best_bpb) / baseline_bpb * 100:.2f}%)")
print(f"Best experiment:   {best_row['description']}")
print()

# How many experiments to find each improvement
print("Cumulative effort per improvement:")
kept_sorted = kept.reset_index()
for i, (_, row) in enumerate(kept_sorted.iterrows()):
    desc = str(row["description"]).strip()
    print(f"  Experiment #{row['index']:3d}: bpb={row['val_bpb']:.6f}  {desc}")
# Out:
# Baseline val_bpb:  1.228006
# Best val_bpb:      0.517530
# Total improvement: 0.710476 (57.86%)
# Best experiment:   DEPTH=3 n_embd=320 AR=96 GPU1 (997 steps NEW BEST)
#
# Cumulative effort per improvement:
#   Experiment #  0: bpb=1.228006  baseline
#   Experiment #  2: bpb=1.028962  DEPTH=6: 36 steps 18.9M tokens 42K tok/sec
#   Experiment #  3: bpb=0.794208  DEPTH=4 (--depth 4): 62 steps 32.5M tokens 89K tok/sec
#   Experiment #  4: bpb=0.777060  WARMDOWN_RATIO 0.5->0.3: GPU0 result
#   Experiment #  5: bpb=0.775165  WARMDOWN_RATIO 0.5->0.3: GPU1 result (best)
#   Experiment #  6: bpb=0.769305  WARMDOWN=0.2 DEPTH=4 GPU0
#   Experiment #  7: bpb=0.757124  WARMDOWN=0.2 DEPTH=3 GPU1 (new best)
#   Experiment #  8: bpb=0.751611  WARMDOWN=0.1 DEPTH=3 GPU0
#   Experiment #  9: bpb=0.707381  WARMDOWN=0.1 DEPTH=2 GPU1 (best: 137 steps)
#   Experiment # 10: bpb=0.704718  DEPTH=2 WARMDOWN=0.1 batch=32 GPU0 (after ollama stop)
#   Experiment # 11: bpb=0.701946  DEPTH=2 WARMDOWN=0.1 batch=32 GPU1 (new best: 141 steps 227K t/s)
#   Experiment # 17: bpb=0.697069  MATRIX_LR=0.06 GPU1 (141 steps, new best)
#   Experiment # 19: bpb=0.677509  ASPECT_RATIO=128 n_embd=256 LR=0.06 GPU1 (96 steps 50M tok NEW BEST)
#   Experiment # 20: bpb=0.676671  MATRIX_LR=0.08 n_embd=256 GPU0 (95 steps new best)
#   Experiment # 26: bpb=0.672712  WARMDOWN=0.15 GPU0 (new best)
#   Experiment # 35: bpb=0.650603  HEAD_DIM=64 ASPECT_RATIO=96 n_embd=192 GPU1 (129 steps NEW BEST)
#   Experiment # 42: bpb=0.606253  TOTAL_BATCH=2^18 GPU0 (246 steps 62M tok NEW BEST)
#   Experiment # 43: bpb=0.601585  TOTAL_BATCH=2^17 GPU1 (482 steps 63M tok BEST; smaller batch=more steps)
#   Experiment # 44: bpb=0.563299  TOTAL_BATCH=2^16 GPU0 (939 steps 61M tok NEW BEST)
#   Experiment # 46: bpb=0.563205  TOTAL_BATCH=2^15 GPU0 (1832 steps 60M tok; same as 2^16 but half VRAM)
#   Experiment # 48: bpb=0.550721  n_embd=256 AR=128 2^15 GPU0 (1549 steps 50M tok NEW BEST)
#   Experiment # 49: bpb=0.559632  WARMDOWN=0.25 2^16 GPU1 (better than 0.15 at 939 steps)
#   Experiment # 50: bpb=0.545657  n_embd=256 WARMDOWN=0.25 GPU0 (1529 steps new best)
#   Experiment # 51: bpb=0.537454  n_embd=320 AR=160 WARMDOWN=0.25 GPU1 (1293 steps 42M tok BEST)
#   Experiment # 52: bpb=0.534312  n_embd=384 AR=192 GPU0 (1136 steps 37M tok NEW BEST)
#   Experiment # 55: bpb=0.531618  MATRIX_LR=0.06 GPU1 (better than 0.08; NEW BEST)
#   Experiment # 57: bpb=0.531004  MATRIX_LR=0.05 GPU1 (marginal new best)
#   Experiment # 59: bpb=0.529474  WARMDOWN=0.30 GPU1 (new best! more cooldown helps)
#   Experiment # 60: bpb=0.527978  WARMDOWN=0.35 GPU0 (better; more cooldown keeps winning)
#   Experiment # 61: bpb=0.526829  WARMDOWN=0.40 GPU1 (new best; long cooldown=better)
#   Experiment # 62: bpb=0.526012  WARMDOWN=0.50 GPU0 (still improving)
#   Experiment # 63: bpb=0.525183  WARMDOWN=0.60 GPU1 (new best; 60% cooldown works!)
#   Experiment # 65: bpb=0.525120  WARMDOWN=0.80 GPU1 (tied with 0.60; plateau reached)
#   Experiment # 66: bpb=0.524714  WEIGHT_DECAY=0.1 GPU0 (marginal best; lower WD better for 384)
#   Experiment # 69: bpb=0.523885  EMBEDDING_LR=0.8 GPU1 (new best)
#   Experiment # 73: bpb=0.522506  ADAM beta2=0.99 GPU1 (new best; more stable second moment)
#   Experiment # 77: bpb=0.517530  DEPTH=3 n_embd=320 AR=96 GPU1 (997 steps NEW BEST)

# %% [markdown]
# ## Top Hits (Kept Experiments by Improvement)

# %%
# Each kept experiment's delta is measured vs the previous kept experiment's bpb
# (since experiments are cumulative -- each one builds on the last kept state)
kept = df[df["status"] == "KEEP"].copy()
kept["prev_bpb"] = kept["val_bpb"].shift(1)
kept["delta"] = kept["prev_bpb"] - kept["val_bpb"]

# Drop baseline (no delta)
hits = kept.iloc[1:].copy()

# Sort by delta improvement (biggest first)
hits = hits.sort_values("delta", ascending=False)

print(f"{'Rank':>4}  {'Delta':>8}  {'BPB':>10}  Description")
print("-" * 80)
for rank, (_, row) in enumerate(hits.iterrows(), 1):
    print(f"{rank:4d}  {row['delta']:+.6f}  {row['val_bpb']:.6f}  {row['description']}")

print(f"\n{'':>4}  {hits['delta'].sum():+.6f}  {'':>10}  TOTAL improvement over baseline")
# Out:
# Rank     Delta         BPB  Description
# --------------------------------------------------------------------------------
#    1  +0.234754  0.794208  DEPTH=4 (--depth 4): 62 steps 32.5M tokens 89K tok/sec
#    2  +0.199044  1.028962  DEPTH=6: 36 steps 18.9M tokens 42K tok/sec
#    3  +0.044350  0.606253  TOTAL_BATCH=2^18 GPU0 (246 steps 62M tok NEW BEST)
#    4  +0.044230  0.707381  WARMDOWN=0.1 DEPTH=2 GPU1 (best: 137 steps)
#    5  +0.038286  0.563299  TOTAL_BATCH=2^16 GPU0 (939 steps 61M tok NEW BEST)
#    6  +0.022109  0.650603  HEAD_DIM=64 ASPECT_RATIO=96 n_embd=192 GPU1 (129 steps NEW BEST)
#    7  +0.019560  0.677509  ASPECT_RATIO=128 n_embd=256 LR=0.06 GPU1 (96 steps 50M tok NEW BEST)
#    8  +0.017148  0.777060  WARMDOWN_RATIO 0.5->0.3: GPU0 result
#    9  +0.013975  0.545657  n_embd=256 WARMDOWN=0.25 GPU0 (1529 steps new best)
#   10  +0.012484  0.550721  n_embd=256 AR=128 2^15 GPU0 (1549 steps 50M tok NEW BEST)
#   11  +0.012181  0.757124  WARMDOWN=0.2 DEPTH=3 GPU1 (new best)
#   12  +0.008203  0.537454  n_embd=320 AR=160 WARMDOWN=0.25 GPU1 (1293 steps 42M tok BEST)
#   13  +0.005860  0.769305  WARMDOWN=0.2 DEPTH=4 GPU0
#   14  +0.005513  0.751611  WARMDOWN=0.1 DEPTH=3 GPU0
#   15  +0.004976  0.517530  DEPTH=3 n_embd=320 AR=96 GPU1 (997 steps NEW BEST)
#   16  +0.004877  0.697069  MATRIX_LR=0.06 GPU1 (141 steps, new best)
#   17  +0.004668  0.601585  TOTAL_BATCH=2^17 GPU1 (482 steps 63M tok BEST; smaller batch=more steps)
#   18  +0.003959  0.672712  WARMDOWN=0.15 GPU0 (new best)
#   19  +0.003142  0.534312  n_embd=384 AR=192 GPU0 (1136 steps 37M tok NEW BEST)
#   20  +0.002772  0.701946  DEPTH=2 WARMDOWN=0.1 batch=32 GPU1 (new best: 141 steps 227K t/s)
#   21  +0.002694  0.531618  MATRIX_LR=0.06 GPU1 (better than 0.08; NEW BEST)
#   22  +0.002663  0.704718  DEPTH=2 WARMDOWN=0.1 batch=32 GPU0 (after ollama stop)
#   23  +0.001895  0.775165  WARMDOWN_RATIO 0.5->0.3: GPU1 result (best)
#   24  +0.001530  0.529474  WARMDOWN=0.30 GPU1 (new best! more cooldown helps)
#   25  +0.001496  0.527978  WARMDOWN=0.35 GPU0 (better; more cooldown keeps winning)
#   26  +0.001379  0.522506  ADAM beta2=0.99 GPU1 (new best; more stable second moment)
#   27  +0.001149  0.526829  WARMDOWN=0.40 GPU1 (new best; long cooldown=better)
#   28  +0.000838  0.676671  MATRIX_LR=0.08 n_embd=256 GPU0 (95 steps new best)
#   29  +0.000829  0.525183  WARMDOWN=0.60 GPU1 (new best; 60% cooldown works!)
#   30  +0.000829  0.523885  EMBEDDING_LR=0.8 GPU1 (new best)
#   31  +0.000817  0.526012  WARMDOWN=0.50 GPU0 (still improving)
#   32  +0.000614  0.531004  MATRIX_LR=0.05 GPU1 (marginal new best)
#   33  +0.000406  0.524714  WEIGHT_DECAY=0.1 GPU0 (marginal best; lower WD better for 384)
#   34  +0.000094  0.563205  TOTAL_BATCH=2^15 GPU0 (1832 steps 60M tok; same as 2^16 but half VRAM)
#   35  +0.000063  0.525120  WARMDOWN=0.80 GPU1 (tied with 0.60; plateau reached)
#   36  -0.008911  0.559632  WARMDOWN=0.25 2^16 GPU1 (better than 0.15 at 939 steps)
#
#       +0.710476              TOTAL improvement over baseline
